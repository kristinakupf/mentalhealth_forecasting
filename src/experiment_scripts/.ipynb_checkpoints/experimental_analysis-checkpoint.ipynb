# %% [markdown]
# # Experiment output analysis

# %%
import numpy as np
import pandas as pd
import pathlib
import os

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, mean_pinball_loss

# %% [markdown]
# ## Set experiment design parameters

# %%
experiments = [
    "autoarima",
    "autogluon_NaiveModel",
    "autogluon_SeasonalNaiveModel",
    "autogluon_ARIMAModel",
    "autogluon_ETSModel",
    "autogluon_AutoETSModel",
    "autogluon_DLinearModel",
    "autogluon_DeepARModel",
    "autogluon_DirectTabularModel",
    "autogluon_RecursiveTabularModel",
    # "autogluon_SimpleFeedForwardModel",
    "autogluon_TemporalFusionTransformerModel",
    "neuralprophet_uni",
    "neuralprophet_covariates",
    "neuralprophet_covariates_onlyclimate",
    "neuralprophet_covariates_noclimate",
    "autogluon_with_covariates_TemporalFusionTransformerModel",
    "autogluon_with_scaled_covariates_DirectTabularModel",
    "autogluon_with_covariates_Energy_EXCAUS_TemporalFusionTransformerModel",
    "autogluon_preset_best_quality_global_model_best_quality",
    "autogluon_global_with_covariates_experiment_TemporalFusionTransformerModel",
    "autogluon_global_with_covariates_experiment_DirectTabularModel",
    "autogluon_global_with_scaled_covariates_experiment_preset_best_quality",
    "autogluon_global_with_scaled_covariates_experiment_TemporalFusionTransformerModel",
    "autogluon_with_scaled_covariates_mean_SWE_TemporalFusionTransformerModel",
    "autogluon_with_scaled_covariates_mean_SWE_DirectTabularModel",
    "autogluon_with_scaled_covariates_TemporalFusionTransformerModel",
]

# %%
report_sim_dates = open("./data_files/experiment_cutoff_dates.txt", 'r').read().split()

# %%
report_sim_dates
# Out:
# ['2017-07-01',
#  '2018-07-01',
#  '2019-07-01',
#  '2020-07-01',
#  '2021-07-01',
#  '2022-07-01']

# %% [markdown]
# ## Load target data

# %%
foodprice_df = pd.read_csv("./datasets/food_CPI.csv", index_col=0)
foodprice_df.index = pd.to_datetime(foodprice_df.index)
foodprice_df.tail()
# Out:
#             Bakery and cereal products (excluding baby food)  \
# REF_DATE
# 2023-05-01                                             198.9
# 2023-06-01                                             197.7
# 2023-07-01                                             199.3
# 2023-08-01                                             197.9
# 2023-09-01                                             196.7
#
#             Dairy products and eggs  Fish, seafood and other marine products  \
# REF_DATE
# 2023-05-01                    170.2                                    166.5
# 2023-06-01                    169.8                                    166.0
# 2023-07-01                    170.8                                    164.3
# 2023-08-01                    168.8                                    165.1
# 2023-09-01                    169.1                                    165.1
#
#             Food purchased from restaurants   Food  \
# REF_DATE
# 2023-05-01                            186.4  184.6
# 2023-06-01                            187.0  184.8
# 2023-07-01                            188.1  185.5
# 2023-08-01                            189.0  185.3
# 2023-09-01                            189.3  185.2
#
#             Fruit, fruit preparations and nuts   Meat  \
# REF_DATE
# 2023-05-01                               168.6  203.2
# 2023-06-01                               172.4  204.0
# 2023-07-01                               166.6  206.7
# 2023-08-01                               164.6  206.6
# 2023-09-01                               165.9  207.5
#
#             Other food products and non-alcoholic beverages  \
# REF_DATE
# 2023-05-01                                            173.5
# 2023-06-01                                            173.0
# 2023-07-01                                            173.8
# 2023-08-01                                            174.9
# 2023-09-01                                            173.7
#
#             Vegetables and vegetable preparations
# REF_DATE
# 2023-05-01                                  185.6
# 2023-06-01                                  183.0
# 2023-07-01                                  185.2
# 2023-08-01                                  182.5
# 2023-09-01                                  180.9

# %%
target_categories = foodprice_df.columns.to_list()
target_categories
# Out:
# ['Bakery and cereal products (excluding baby food)',
#  'Dairy products and eggs',
#  'Fish, seafood and other marine products',
#  'Food purchased from restaurants',
#  'Food',
#  'Fruit, fruit preparations and nuts',
#  'Meat',
#  'Other food products and non-alcoholic beverages',
#  'Vegetables and vegetable preparations']

# %% [markdown]
# ## Define metric functions

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

def pinball_loss(y_true, y_pred_quantiles, quantiles):
    losses = {}
    for q in quantiles:
        col = f"q_{q}"
        y_pred = y_pred_quantiles[col].values
        pb_loss = mean_pinball_loss(y_true, y_pred, alpha=q)
        losses[col] = pb_loss
    return pd.Series(losses)

def average_pinball_loss(y_true, y_pred_quantiles, quantiles):
    return pinball_loss(y_true, y_pred_quantiles, quantiles).mean()

point_metrics = {
    'r2_score': r2_score,
    'mae': mean_absolute_error,
    'mape': mean_absolute_percentage_error,
    'mse': mean_squared_error,
    'rmse': rmse
}

# %% [markdown]
# ## Compute metrics for median forecasts

# %%
def compute_all_scores(study_dates, study_metric='mape'):

    # Prepare an empty list to store the results
    results = []

    for exp_name in experiments:
        for category in target_categories:
            scores = []

            for cutoff_date in study_dates:

                forecast_csv_path = f"./output/experiments/{exp_name}/{cutoff_date}/forecasts/{category}.csv"
                forecast_df = pd.read_csv(forecast_csv_path, index_col=0)
                forecast_df.index = pd.to_datetime(forecast_df.index)

                actual_df = foodprice_df[category].loc[[date for date in forecast_df.index if date in foodprice_df.index]]

                if study_metric in point_metrics:
                    median_col = "q_0.5"
                    y_pred = forecast_df[median_col]
                    y_true = actual_df
                    if len(y_pred) > len(y_true):
                        y_pred = y_pred[:len(y_true)]
                    scores.append(point_metrics[study_metric](y_true=y_true, y_pred=y_pred))
                    
                elif study_metric == 'pinball_loss':
                    y_pred = forecast_df
                    y_true = actual_df
                    if len(y_pred) > len(y_true):
                        y_pred = y_pred[:len(y_true)]
                    scores.append(average_pinball_loss(y_true=y_true, y_pred_quantiles=y_pred, quantiles=[0.01, 0.05, 0.1, 0.25, 0.75, 0.9, 0.95, 0.99]))
            
            mean_score = np.mean(scores)
            std_score = np.std(scores)

            # Append the result as a dictionary to the results list
            results.append({
                'experiment': exp_name,
                'category': category,
                'mean_score': mean_score,
                'std_score': std_score
            })

    # Convert the results list to a DataFrame
    return pd.DataFrame(results)

# %% [markdown]
# # plotting code

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

def plot_quantile_forecasts(category, context_df, forecast_dfs, actual_df, cutoff_dates, save_path=None, show_plots=True, model_name=""):

    fig, ax = plt.subplots(figsize=(10,6))

    # Context
    context_df = pd.concat((context_df, actual_df))
    ax.plot(context_df.index, context_df.values, color='black', label='Historical CPI')

    for index, forecast_df in enumerate(forecast_dfs):
    
        # Confidence range between 0.01 and 0.99 quantiles
        ax.fill_between(
            forecast_df.index,
            forecast_df[f"q_0.05"],
            forecast_df[f"q_0.95"],
            facecolor='purple',
            alpha=0.5,
            label='95% Confidence' if index == 0 else None
        )

        # Add a line trace for the median
        ax.plot(
            forecast_df.index, 
            forecast_df[f"q_0.5"], 
            color='purple', 
            label='Median Forecast' if index == 0 else None
            )

    # Update the layout as needed
    ax.set_title(f'{category}\nRetrospective Forecast\n{model_name}')
    ax.set_xlabel('Date')
    ax.set_ylabel('CPI (% 2002 Prices)')
    for cutoff_date in cutoff_dates:
        ax.axvline(pd.to_datetime(cutoff_date), color='black', ls='--', ms=1, alpha=0.5)
    ax.legend()
    ax.xaxis.set_major_locator(mdates.YearLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
    plt.xticks(rotation=45)

    # Show the figure
    plt.grid(axis='y')

    if show_plots:
        plt.show()

    # Save the figure if the path is specified
    if save_path:
        fig.savefig(save_path, dpi=300 if save_path.endswith("png") else None) # High res for png

# %% [markdown]
# # 6-year analysis

# %%
mape_df = compute_all_scores(report_sim_dates, 'mape')
mape_df
# Out:
#                                             experiment  \
# 0                                            autoarima
# 1                                            autoarima
# 2                                            autoarima
# 3                                            autoarima
# 4                                            autoarima
# ..                                                 ...
# 229  autogluon_with_scaled_covariates_TemporalFusio...
# 230  autogluon_with_scaled_covariates_TemporalFusio...
# 231  autogluon_with_scaled_covariates_TemporalFusio...
# 232  autogluon_with_scaled_covariates_TemporalFusio...
# 233  autogluon_with_scaled_covariates_TemporalFusio...
#
#                                              category  mean_score  std_score
# 0    Bakery and cereal products (excluding baby food)    0.035366   0.030408
# 1                             Dairy products and eggs    0.025163   0.017658
# 2             Fish, seafood and other marine products    0.019045   0.012768
# 3                     Food purchased from restaurants    0.014273   0.012254
# 4                                                Food    0.022689   0.020306
# ..                                                ...         ...        ...
# 229                                              Food    0.027078   0.020568
# 230                Fruit, fruit preparations and nuts    0.048208   0.029262
# 231                                              Meat    0.048266   0.015079
# 232   Other food products and non-alcoholic beverages    0.026769   0.021631
# 233             Vegetables and vegetable preparations    0.051744   0.015297
#
# [234 rows x 4 columns]

# %%
mape_df.loc[mape_df.experiment == "neuralprophet_covariates"].sort_values('category')
# Out:
#                    experiment  \
# 108  neuralprophet_covariates
# 109  neuralprophet_covariates
# 110  neuralprophet_covariates
# 112  neuralprophet_covariates
# 111  neuralprophet_covariates
# 113  neuralprophet_covariates
# 114  neuralprophet_covariates
# 115  neuralprophet_covariates
# 116  neuralprophet_covariates
#
#                                              category  mean_score  std_score
# 108  Bakery and cereal products (excluding baby food)    0.110942   0.020555
# 109                           Dairy products and eggs    0.111058   0.029450
# 110           Fish, seafood and other marine products    0.097273   0.020510
# 112                                              Food    0.095715   0.037558
# 111                   Food purchased from restaurants    0.102842   0.017581
# 113                Fruit, fruit preparations and nuts    0.090027   0.007983
# 114                                              Meat    0.112895   0.023521
# 115   Other food products and non-alcoholic beverages    0.103644   0.034967
# 116             Vegetables and vegetable preparations    0.128335   0.014102

# %%
mape_df.loc[mape_df.experiment == "neuralprophet_covariates_onlyclimate"].sort_values('category')
# Out:
#                                experiment  \
# 117  neuralprophet_covariates_onlyclimate
# 118  neuralprophet_covariates_onlyclimate
# 119  neuralprophet_covariates_onlyclimate
# 121  neuralprophet_covariates_onlyclimate
# 120  neuralprophet_covariates_onlyclimate
# 122  neuralprophet_covariates_onlyclimate
# 123  neuralprophet_covariates_onlyclimate
# 124  neuralprophet_covariates_onlyclimate
# 125  neuralprophet_covariates_onlyclimate
#
#                                              category  mean_score  std_score
# 117  Bakery and cereal products (excluding baby food)    0.117316   0.021520
# 118                           Dairy products and eggs    0.105782   0.022929
# 119           Fish, seafood and other marine products    0.065692   0.017596
# 121                                              Food    0.075969   0.031871
# 120                   Food purchased from restaurants    0.070464   0.023738
# 122                Fruit, fruit preparations and nuts    0.071484   0.013656
# 123                                              Meat    0.063008   0.008739
# 124   Other food products and non-alcoholic beverages    0.091628   0.042607
# 125             Vegetables and vegetable preparations    0.078928   0.015474

# %%
mape_df.loc[mape_df.experiment == "neuralprophet_covariates_noclimate"].sort_values('category')
# Out:
#                              experiment  \
# 126  neuralprophet_covariates_noclimate
# 127  neuralprophet_covariates_noclimate
# 128  neuralprophet_covariates_noclimate
# 130  neuralprophet_covariates_noclimate
# 129  neuralprophet_covariates_noclimate
# 131  neuralprophet_covariates_noclimate
# 132  neuralprophet_covariates_noclimate
# 133  neuralprophet_covariates_noclimate
# 134  neuralprophet_covariates_noclimate
#
#                                              category  mean_score  std_score
# 126  Bakery and cereal products (excluding baby food)    0.080683   0.029066
# 127                           Dairy products and eggs    0.080159   0.026086
# 128           Fish, seafood and other marine products    0.076829   0.041895
# 130                                              Food    0.062422   0.022680
# 129                   Food purchased from restaurants    0.070188   0.028490
# 131                Fruit, fruit preparations and nuts    0.086385   0.023943
# 132                                              Meat    0.076348   0.026273
# 133   Other food products and non-alcoholic beverages    0.073676   0.030261
# 134             Vegetables and vegetable preparations    0.090768   0.032159

# %%
mape_df.loc[mape_df.category == "Bakery and cereal products (excluding baby food)"].sort_values('mean_score')
# Out:
#                                             experiment  \
# 36                                  autogluon_ETSModel
# 45                              autogluon_AutoETSModel
# 27                                autogluon_ARIMAModel
# 81                     autogluon_RecursiveTabularModel
# 162  autogluon_preset_best_quality_global_model_bes...
# 9                                 autogluon_NaiveModel
# 18                        autogluon_SeasonalNaiveModel
# 189  autogluon_global_with_scaled_covariates_experi...
# 0                                            autoarima
# 54                              autogluon_DLinearModel
# 63                               autogluon_DeepARModel
# 171  autogluon_global_with_covariates_experiment_Te...
# 207  autogluon_with_scaled_covariates_mean_SWE_Temp...
# 198  autogluon_global_with_scaled_covariates_experi...
# 153  autogluon_with_covariates_Energy_EXCAUS_Tempor...
# 225  autogluon_with_scaled_covariates_TemporalFusio...
# 135  autogluon_with_covariates_TemporalFusionTransf...
# 90            autogluon_TemporalFusionTransformerModel
# 180  autogluon_global_with_covariates_experiment_Di...
# 99                                   neuralprophet_uni
# 216  autogluon_with_scaled_covariates_mean_SWE_Dire...
# 144  autogluon_with_scaled_covariates_DirectTabular...
# 126                 neuralprophet_covariates_noclimate
# 108                           neuralprophet_covariates
# 117               neuralprophet_covariates_onlyclimate
# 72                        autogluon_DirectTabularModel
#
#                                              category  mean_score  std_score
# 36   Bakery and cereal products (excluding baby food)    0.023074   0.023828
# 45   Bakery and cereal products (excluding baby food)    0.027251   0.025498
# 27   Bakery and cereal products (excluding baby food)    0.030631   0.026165
# 81   Bakery and cereal products (excluding baby food)    0.031129   0.029383
# 162  Bakery and cereal products (excluding baby food)    0.032415   0.025172
# 9    Bakery and cereal products (excluding baby food)    0.034179   0.031818
# 18   Bakery and cereal products (excluding baby food)    0.034179   0.031818
# 189  Bakery and cereal products (excluding baby food)    0.034484   0.029024
# 0    Bakery and cereal products (excluding baby food)    0.035366   0.030408
# 54   Bakery and cereal products (excluding baby food)    0.035783   0.025914
# 63   Bakery and cereal products (excluding baby food)    0.038222   0.031443
# 171  Bakery and cereal products (excluding baby food)    0.040160   0.033955
# 207  Bakery and cereal products (excluding baby food)    0.043390   0.033723
# 198  Bakery and cereal products (excluding baby food)    0.043465   0.040673
# 153  Bakery and cereal products (excluding baby food)    0.043470   0.032987
# 225  Bakery and cereal products (excluding baby food)    0.046103   0.040984
# 135  Bakery and cereal products (excluding baby food)    0.047335   0.040692
# 90   Bakery and cereal products (excluding baby food)    0.047447   0.034146
# 180  Bakery and cereal products (excluding baby food)    0.049357   0.056071
# 99   Bakery and cereal products (excluding baby food)    0.057232   0.045761
# 216  Bakery and cereal products (excluding baby food)    0.059651   0.062340
# 144  Bakery and cereal products (excluding baby food)    0.060463   0.058057
# 126  Bakery and cereal products (excluding baby food)    0.080683   0.029066
# 108  Bakery and cereal products (excluding baby food)    0.110942   0.020555
# 117  Bakery and cereal products (excluding baby food)    0.117316   0.021520
# 72   Bakery and cereal products (excluding baby food)    0.315683   0.042457

# %%
# Top 3

best_scores = mape_df.loc[mape_df.category == "Bakery and cereal products (excluding baby food)"].sort_values('mean_score')
best_scores.iloc[:3]
# Out:
#                 experiment                                          category  \
# 36      autogluon_ETSModel  Bakery and cereal products (excluding baby food)
# 45  autogluon_AutoETSModel  Bakery and cereal products (excluding baby food)
# 27    autogluon_ARIMAModel  Bakery and cereal products (excluding baby food)
#
#     mean_score  std_score
# 36    0.023074   0.023828
# 45    0.027251   0.025498
# 27    0.030631   0.026165

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

def plot_forecasts(category, context_df, forecast_dfs_by_method, actual_df, cutoff_dates, save_path=None, show_plots=True):

    # Create a figure with specified size
    fig = plt.figure(figsize=(12,6))

    # Define the positions of the axes and create them
    plot_ax = fig.add_axes([0.1, 0.1, 0.65, 0.8])  # left, bottom, width, height (range 0 to 1)
    legend_ax = fig.add_axes([0.77, 0.1, 0.2, 0.8])
    legend_ax.axis('off')  # Turn off the axes for the legend, so it's not visible


    # Combine context and actual data
    combined_df = pd.concat((context_df, actual_df))
    plot_ax.plot(combined_df.index, combined_df.values, color='black', label='Historical')

    colors = ['purple', 'orange', 'red']  # specify more colors if you have more methods

    for method_index, (method, forecast_dfs) in enumerate(forecast_dfs_by_method.items()):
        color = colors[method_index % len(colors)]

        for index, forecast_df in enumerate(forecast_dfs):
            # Confidence range between 0.05 and 0.95 quantiles (assuming these columns exist)
            plot_ax.fill_between(
                forecast_df.index,
                forecast_df["q_0.05"],
                forecast_df["q_0.95"],
                facecolor=color,
                alpha=0.2,
                label=f'95% Confidence ({method})' if index == 0 else None  # label only the first instance
            )

            # Add a line trace for the median
            plot_ax.plot(
                forecast_df.index,
                forecast_df["q_0.5"],
                color=color,
                # label=f'Median Forecast ({method})' if index == 0 else None  # label only the first instance
            )

    # Update the layout as needed
    plot_ax.set_title(f'{category} Price Forecast Comparison')
    plot_ax.set_xlabel('Date')
    plot_ax.set_ylabel('Price')
    for cutoff_date in cutoff_dates:
        plot_ax.axvline(pd.to_datetime(cutoff_date), color='black', ls='--', lw=1, alpha=0.5)

    # Generate legend from the plot_ax and apply it onto legend_ax
    handles, labels = plot_ax.get_legend_handles_labels()
    legend_ax.legend(handles, labels, loc='center left')

    plot_ax.xaxis.set_major_locator(mdates.YearLocator())
    plot_ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
    plt.xticks(rotation=45)
    plot_ax.grid(axis='y')

    # Show or save the figure based on input flags
    if show_plots:
        plt.show()

    if save_path:
        fig.savefig(save_path, dpi=300 if save_path.endswith("png") else None)  # High res for png



# Assuming foodprice_df and mape_df are predefined
cutoff_dates = report_sim_dates

for category in foodprice_df.columns:
    
    best_scores = mape_df.loc[mape_df.category == category].sort_values('mean_score').iloc[:3]
    context_df = foodprice_df.loc[(foodprice_df.index > "2010-01-01") & (foodprice_df.index <= cutoff_dates[0])][category]
    actual_df = foodprice_df.loc[foodprice_df.index >= cutoff_dates[0]][category]

    forecast_dfs_by_method = {}  # a dictionary {method_name: forecast_dfs}

    # iterate over the most accurate experiments (i.e. model configurations)
    for index, (exp, cat, mean_score, std_score) in best_scores.iterrows():
        forecast_dfs = []

        # for each annual date in the list of cutoff dates, get this experiment's forecasts
        for date in cutoff_dates:
            forecast_csv_path = f"./output/experiments/{exp}/{date}/forecasts/{category}.csv"
            forecast_df = pd.read_csv(forecast_csv_path, index_col=0).iloc[-18:]
            forecast_df.index = pd.to_datetime(forecast_df.index)
            forecast_dfs.append(forecast_df)

        forecast_dfs_by_method[exp] = forecast_dfs

    # plot this experiment's forecasts along with the data in context_df and actual_df, which are the historical data
    plot_forecasts(
        category=category, 
        context_df=context_df, 
        forecast_dfs_by_method=forecast_dfs_by_method, 
        actual_df=actual_df, 
        cutoff_dates=cutoff_dates, 
        save_path=f"./output/experiment_analysis/plots/{category}_top3_models.png",  # change as needed
        show_plots=True
    )

# %%
best_results_6_year = []

for category in target_categories:

    # Identify the best-scoring experiment
    min_idx = mape_df.loc[mape_df.category == category]["mean_score"].idxmin()
    min_row = mape_df.loc[mape_df.category == category].loc[min_idx]
    best_results_6_year.append({"category": category, "top_experiment": min_row['experiment'], "mean_score": min_row['mean_score']})

best_results_6_year_df = pd.DataFrame(best_results_6_year)
best_results_6_year_df.to_csv("./output/experiment_analysis/best_results_6_year_single_models.csv")
best_results_6_year_df
# Out:
#                                            category  \
# 0  Bakery and cereal products (excluding baby food)
# 1                           Dairy products and eggs
# 2           Fish, seafood and other marine products
# 3                   Food purchased from restaurants
# 4                                              Food
# 5                Fruit, fruit preparations and nuts
# 6                                              Meat
# 7   Other food products and non-alcoholic beverages
# 8             Vegetables and vegetable preparations
#
#                                       top_experiment  mean_score
# 0                                 autogluon_ETSModel    0.023074
# 1                             autogluon_AutoETSModel    0.020592
# 2  autogluon_global_with_covariates_experiment_Te...    0.016274
# 3                                 autogluon_ETSModel    0.010429
# 4                    autogluon_RecursiveTabularModel    0.019692
# 5                                          autoarima    0.036117
# 6                                 autogluon_ETSModel    0.024303
# 7                    autogluon_RecursiveTabularModel    0.026523
# 8                              autogluon_DeepARModel    0.038039

# %%
cutoff_dates = report_sim_dates

for index, (category, top_experiment, mean_score) in best_results_6_year_df.iterrows():
    forecast_dfs = []
    for date in cutoff_dates:
        forecast_csv_path = f"./output/experiments/{top_experiment}/{date}/forecasts/{category}.csv"
        forecast_df = pd.read_csv(forecast_csv_path, index_col=0).iloc[-18:]
        forecast_df.index = pd.to_datetime(forecast_df.index)
        forecast_dfs.append(forecast_df)
    combined_forecast_df = pd.concat(forecast_dfs, axis=0)
    context_df = foodprice_df.loc[(foodprice_df.index > "2010-01-01") & (foodprice_df.index <= cutoff_dates[0])][category]
    actual_df = foodprice_df.loc[foodprice_df.index >= cutoff_dates[0]][category]
    plot_quantile_forecasts(category, context_df, forecast_dfs, actual_df, cutoff_dates, model_name=f"6-year best model: {top_experiment}")

# %% [markdown]
# # 2-year analysis

# %%
mape_df = compute_all_scores(report_sim_dates[-2:], 'mape')
mape_df
# Out:
#                                             experiment  \
# 0                                            autoarima
# 1                                            autoarima
# 2                                            autoarima
# 3                                            autoarima
# 4                                            autoarima
# ..                                                 ...
# 229  autogluon_with_scaled_covariates_TemporalFusio...
# 230  autogluon_with_scaled_covariates_TemporalFusio...
# 231  autogluon_with_scaled_covariates_TemporalFusio...
# 232  autogluon_with_scaled_covariates_TemporalFusio...
# 233  autogluon_with_scaled_covariates_TemporalFusio...
#
#                                              category  mean_score  std_score
# 0    Bakery and cereal products (excluding baby food)    0.078149   0.000364
# 1                             Dairy products and eggs    0.049542   0.005377
# 2             Fish, seafood and other marine products    0.027561   0.019110
# 3                     Food purchased from restaurants    0.025209   0.013053
# 4                                                Food    0.050105   0.009264
# ..                                                ...         ...        ...
# 229                                              Food    0.055649   0.004678
# 230                Fruit, fruit preparations and nuts    0.082665   0.003146
# 231                                              Meat    0.061904   0.014248
# 232   Other food products and non-alcoholic beverages    0.053931   0.016071
# 233             Vegetables and vegetable preparations    0.038912   0.002843
#
# [234 rows x 4 columns]

# %%
mape_df.loc[mape_df.category == "Vegetables and vegetable preparations"].sort_values('mean_score')
# Out:
#                                             experiment  \
# 98            autogluon_TemporalFusionTransformerModel
# 143  autogluon_with_covariates_TemporalFusionTransf...
# 233  autogluon_with_scaled_covariates_TemporalFusio...
# 215  autogluon_with_scaled_covariates_mean_SWE_Temp...
# 71                               autogluon_DeepARModel
# 206  autogluon_global_with_scaled_covariates_experi...
# 179  autogluon_global_with_covariates_experiment_Te...
# 107                                  neuralprophet_uni
# 62                              autogluon_DLinearModel
# 197  autogluon_global_with_scaled_covariates_experi...
# 35                                autogluon_ARIMAModel
# 44                                  autogluon_ETSModel
# 170  autogluon_preset_best_quality_global_model_bes...
# 17                                autogluon_NaiveModel
# 26                        autogluon_SeasonalNaiveModel
# 53                              autogluon_AutoETSModel
# 8                                            autoarima
# 89                     autogluon_RecursiveTabularModel
# 134                 neuralprophet_covariates_noclimate
# 125               neuralprophet_covariates_onlyclimate
# 161  autogluon_with_covariates_Energy_EXCAUS_Tempor...
# 224  autogluon_with_scaled_covariates_mean_SWE_Dire...
# 116                           neuralprophet_covariates
# 152  autogluon_with_scaled_covariates_DirectTabular...
# 188  autogluon_global_with_covariates_experiment_Di...
# 80                        autogluon_DirectTabularModel
#
#                                   category  mean_score  std_score
# 98   Vegetables and vegetable preparations    0.030572   0.006902
# 143  Vegetables and vegetable preparations    0.032742   0.005378
# 233  Vegetables and vegetable preparations    0.038912   0.002843
# 215  Vegetables and vegetable preparations    0.041597   0.002803
# 71   Vegetables and vegetable preparations    0.048508   0.007842
# 206  Vegetables and vegetable preparations    0.051300   0.020251
# 179  Vegetables and vegetable preparations    0.056569   0.010107
# 107  Vegetables and vegetable preparations    0.056925   0.001109
# 62   Vegetables and vegetable preparations    0.060728   0.000767
# 197  Vegetables and vegetable preparations    0.060741   0.002330
# 35   Vegetables and vegetable preparations    0.062219   0.006984
# 44   Vegetables and vegetable preparations    0.063893   0.007041
# 170  Vegetables and vegetable preparations    0.066970   0.030990
# 17   Vegetables and vegetable preparations    0.072432   0.007907
# 26   Vegetables and vegetable preparations    0.072432   0.007907
# 53   Vegetables and vegetable preparations    0.072432   0.007907
# 8    Vegetables and vegetable preparations    0.074349   0.015939
# 89   Vegetables and vegetable preparations    0.075705   0.013389
# 134  Vegetables and vegetable preparations    0.076695   0.017695
# 125  Vegetables and vegetable preparations    0.081992   0.003387
# 161  Vegetables and vegetable preparations    0.090058   0.025753
# 224  Vegetables and vegetable preparations    0.112876   0.010383
# 116  Vegetables and vegetable preparations    0.113971   0.004686
# 152  Vegetables and vegetable preparations    0.120780   0.002718
# 188  Vegetables and vegetable preparations    0.128517   0.030132
# 80   Vegetables and vegetable preparations    0.403787   0.019343

# %%
best_results_2_year = []

for category in target_categories:

    # Identify the best-scoring experiment
    min_idx = mape_df.loc[mape_df.category == category]["mean_score"].idxmin()
    min_row = mape_df.loc[mape_df.category == category].loc[min_idx]
    best_results_2_year.append({"category": category, "top_experiment": min_row['experiment'], "mean_score": min_row['mean_score']})

best_results_2_year_df = pd.DataFrame(best_results_2_year)
best_results_2_year_df.to_csv("./output/experiment_analysis/best_results_2_year_single_models.csv")
best_results_2_year_df
# Out:
#                                            category  \
# 0  Bakery and cereal products (excluding baby food)
# 1                           Dairy products and eggs
# 2           Fish, seafood and other marine products
# 3                   Food purchased from restaurants
# 4                                              Food
# 5                Fruit, fruit preparations and nuts
# 6                                              Meat
# 7   Other food products and non-alcoholic beverages
# 8             Vegetables and vegetable preparations
#
#                                       top_experiment  mean_score
# 0                                 autogluon_ETSModel    0.044298
# 1           autogluon_TemporalFusionTransformerModel    0.030315
# 2                                 autogluon_ETSModel    0.024752
# 3                                 autogluon_ETSModel    0.016717
# 4           autogluon_TemporalFusionTransformerModel    0.035676
# 5           autogluon_TemporalFusionTransformerModel    0.050232
# 6  autogluon_with_covariates_TemporalFusionTransf...    0.031795
# 7  autogluon_with_scaled_covariates_TemporalFusio...    0.053931
# 8           autogluon_TemporalFusionTransformerModel    0.030572

# %%
cutoff_dates = report_sim_dates[-2:]

for index, (category, top_experiment, mean_score) in best_results_2_year_df.iterrows():
    forecast_dfs = []
    for date in cutoff_dates:
        forecast_csv_path = f"./output/experiments/{top_experiment}/{date}/forecasts/{category}.csv"
        forecast_df = pd.read_csv(forecast_csv_path, index_col=0).iloc[-18:]
        forecast_df.index = pd.to_datetime(forecast_df.index)
        forecast_dfs.append(forecast_df)
    combined_forecast_df = pd.concat(forecast_dfs, axis=0)
    context_df = foodprice_df.loc[(foodprice_df.index > "2010-01-01") & (foodprice_df.index <= cutoff_dates[0])][category]
    actual_df = foodprice_df.loc[foodprice_df.index >= cutoff_dates[0]][category]
    plot_quantile_forecasts(category, context_df, forecast_dfs, actual_df, cutoff_dates, model_name=f"2-year best model: {top_experiment}")

# %% [markdown]
# todo
# - add retrospective analysis for last year
# - want to visualize error over time and compare error across years. We expect that some models were way off last year. Ideally we'd find some models that have good accurracy historically and were able to predict some of the spikes of the last two years. I mean otherwise really what is the point, unless it is to characterize "normal" or expected changes in prices
#
# So, one quick thing to do would be to just check the MAPE over the last two years in the study and compare those to the prior 4 (or however many) years. I bet we'll see completely different models, which begs the question "how should we REALLY be doing model selection?"
