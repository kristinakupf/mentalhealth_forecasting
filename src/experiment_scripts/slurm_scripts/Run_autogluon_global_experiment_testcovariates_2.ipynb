# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Define models that we would like to test that have global capabilities

# %% [markdown]
# Global models are machine learning algorithms that learn a single model from the entire training set consisting of multiple time series. Most global models in AutoGluon are provided by the GluonTS library. These are neural-network algorithms implemented in PyTorch, such as:
#
# DeepAR
#
# PatchTST
#
# DLinear
#
# TemporalFusionTransformer
#
# AutoGluon also offers two tabular global models RecursiveTabular and DirectTabular. Under the hood, these models convert the forecasting task into a regression problem and use a TabularPredictor to fit regression algorithms like LightGBM.

# %%
# EXP_BASE = "connex_groups_autogluon_global_with_scaled_covariates_experiment"
EXP_BASE_OPTIONS = [
            "connex_autogluon_global_with_scaled_covariates_experiment",
            "google_autogluon_global_with_scaled_covariates_experiment",
            "statcan_autogluon_global_with_scaled_covariates_experiment"
           ]


EXP_MODEL_LIST = [
                "DeepARModel",
                "DLinearModel",
                "RecursiveTabularModel",
                "TemporalFusionTransformerModel", 
                "DirectTabularModel", 
                 ]


prediction_length_options = [4,1]

# %%
for EXP_BASE in EXP_BASE_OPTIONS:
    
    keyword = EXP_BASE.split('_')[0]
    print('looking at {} keywords'.format(keyword))
    
    for prediction_length in prediction_length_options:

        #extract keyword from EXP_BASE
        print('Training and evaluating {}'.format(EXP_MODEL_LIST))
        # %run ../'autogluon_experiment_testcovariates.ipynb'
# Out:
# looking at google keywords
# Training and evaluating ['DeepARModel', 'DLinearModel', 'RecursiveTabularModel', 'TemporalFusionTransformerModel', 'DirectTabularModel']
# Duplicate Indices:
# Empty DataFrame
# Columns: [IS_MENTAL_HEALTH, google_anxiety, google_suicide, google_fear, google_loneliness, google_allmentaldistress, google_mortgage, google_mortgageloan, google_unemployment, google_foodbank, google_welfare, google_ei, google_employmentinsurance, google_allfinancialstressors, google_education, google_abuse, google_alcohol, google_divorce, google_allsocialstressors, google_cbt, google_selfcare, google_counselling, google_crisishotline, google_helpline, google_mindfulness, google_alltreatmentseeking, google_sick, google_symptoms, google_cough, google_fever, google_flu, google_rsv, google_allcovidinformation]
# Index: []
#
# [0 rows x 33 columns]
# IS_MENTAL_HEALTH
# google_anxiety
# google_suicide
# google_fear
# google_loneliness
# google_allmentaldistress
# google_mortgage
# ...

# %%
# # Pivoting the DataFrame for input to chat gpt 
# pivoted_df = train_data.pivot(index='timestamp', columns='item_id', values='target')
# pivoted_df.reset_index(inplace=True)

# # Displaying the pivoted DataFrame
# pivoted_df

# pivoted_df.to_csv('/h/kupfersk/mentalhealth_forecasting/src/analysis/test_gpt4.csv')
